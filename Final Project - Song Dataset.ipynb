# %% [markdown]
# # Final Project Master Class Hacktiv8

# %% [markdown]
# Buatlah sebuah notebook dengan ketentuan seperti dibawah ini:
#
# 1. Data yang digunakan dapat diunduh [disini](https://bit.ly/final-project-hacktiv8-song-dataset).
#
# 2. Lakukan Data Cleaning (handling missing values, drop duplicate data).
#
# 3. Tentukan topik dan alasan yang akan dibahas. Contoh :
#   * Topik : `Eksplorasi terhadap data lagu bergenre Rock dan data lagu bergenre EDM.`
#   * Alasan : `Adanya hipotesa bahwa para orang dewasa saat ini lebih menyukai EDM dibanding Rock dilihat dari maraknya konser EDM dibandingkan dengan konser Rock`.
#
# 4. Buat minimal 4 buah diagram yang berkaitan dengan topik pada poin 3.
#
# 5. Narasikan insight yang didapat dari data.
#
# 6. Jangan lupa untuk menyertakan identitas didalam notebook.
#
# File `.ipynb` dikumpulkan paling lambat hari **Jumat, 26 November 2021 pukul 16:30 WIB.**

# %%
import pandas as pd
df = pd.read_csv('final-project-song-dataset.csv')
df
# Out:
#                      track_id  ... track_release_month
# 0      6f807x0ima9a1j3VPbc7VN  ...                   6
# 1      0r7CVbZTWZgbTCYdfa2P31  ...                  12
# 2      1z1Hg7Vb0AhHDiEmnDE79l  ...                   7
# 3      75FpbthrwQmzHlBJLuGdC7  ...                   7
# 4      1e8PAfcKUYoKkxPhrHqw4x  ...                   3
# ...                       ...  ...                 ...
# 32828  7bxnKAamR3snQ1VGLuVfC1  ...                   4
# 32829  5Aevni09Em4575077nkWHz  ...                   3
# 32830  7ImMqPP3Q1yfUHvsdn7wEo  ...                   4
# 32831  2m69mhnfQ1Oq6lGtXuYhgX  ...                   1
# 32832  29zWqhca3zt5NsckZqDf6c  ...                   3
#
# [32833 rows x 25 columns]

# %% [markdown]
# ## Keterangan Column

# %% [markdown]
# <img src='https://i.ibb.co/GRbpJZv/atribut-dataset-final-project.png'>
